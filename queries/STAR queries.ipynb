# %% [markdown]
# # STAR/dimensional schema queries

# %% [markdown]
# * Retrieve the number of memes per year in ascending order, as well as the oldest memes acrosstime categories ("added" and "year")
#
# * Find the top 10 social network origins (excluding ‘unknown’ origin and normalizing terms).
#
# * Which memes have the largest number of common tags?
#
# * Data augmentation. Given a meme, find the most similar memes in the data set based on
#     1)similaritybasedonDandelionAPI cosine similarity using the "description" of each meme asinput and
#     2) the number of common tags.
#
# * Data augmentation. Is it possible to find two memes that have their description similarityscore above 90% but have few tags in common tags?
#
# * Data augmentation. Using the Google Vision data enrichment available data, get the distri-bution of safeness categories (adult, spoof, medical, violence and racy) as percentage of allthe memes analyzed.

# %%
#!conda install -c anaconda psycopg2
#import sys
#!conda install --yes --prefix {sys.prefix} psycopg2

# %%
import pandas as pd
import psycopg2
from psycopg2 import Error

connection = None
try:
    # Connect to an existing database
    connection = psycopg2.connect(user="airflow",
                                  password="airflow",
                                  host="127.0.0.1",
                                  port="5432",
                                  database="airflow")

    # Create a cursor to perform database operations
    cursor = connection.cursor()
    # Print PostgreSQL details
    print("PostgreSQL server information")
    print(connection.get_dsn_parameters(), "\n")
    # Executing a SQL query
    cursor.execute("SELECT version();")
    # Fetch result
    record = cursor.fetchone()
    print("You are connected to - ", record, "\n")

except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
# Out:
# PostgreSQL server information
# {'user': 'airflow', 'dbname': 'airflow', 'host': '127.0.0.1', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'gssencmode': 'prefer', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 13.4 (Debian 13.4-1.pgdg110+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 10.2.1-6) 10.2.1 20210110, 64-bit',)

# %% [markdown]
# ##  Retrieve the number of memes per year in ascending order, as well as the oldest memes acrosstime categories ("added" and "year")

# %% [markdown]
# ### Memes per year in ascending order

# %%
connection.rollback()
query = """
SELECT count(meme_kym_id) as total, year  from memes_dim group by year order by total desc, year ASC LIMIT 10;
"""
dat = pd.read_sql_query(query, connection)
dat.head(10)
# Out:
#    total  year
# 0    807  2011
# 1    756  2010
# 2    584  2016
# 3    522  2012
# 4    509  2014
# 5    500     0
# 6    490  2009
# 7    464  2015
# 8    449  2013
# 9    433  2017

# %% [markdown]
# ### Oldest memes acrosstime categories "year"

# %%
connection.rollback()
query="""
SELECT 
    year, 
    meme_kym_id
FROM memes_dim 
WHERE year>0
ORDER BY year 
ASC LIMIT 10;
"""
dat = pd.read_sql_query(query, connection)
dat.head(10)
# Out:
#    year                     meme_kym_id
# 0  1336                            baka
# 1  1392                          katana
# 2  1495        the-last-supper-parodies
# 3  1503                       mona-lisa
# 4  1561                shits-on-fire-yo
# 5  1590  roses-are-red-violets-are-blue
# 6  1600           tarot-arcana-parodies
# 7  1605                 guy-fawkes-mask
# 8  1700        breaking-the-fourth-wall
# 9  1700                       bamboozle

# %% [markdown]
# ### Oldest memes acrosstime categories "added"

# %%
connection.rollback()
query="""
SELECT 
    cast(to_timestamp(added) as date) AS date_added, 
    meme_kym_id 
FROM memes_dim 
WHERE added > 0
ORDER BY added ASC LIMIT 10;
"""
dat = pd.read_sql_query(query, connection)
dat.head(10)
# Out:
#    date_added                     meme_kym_id
# 0  2008-12-10                        rickroll
# 1  2008-12-10                    technoviking
# 2  2008-12-10    miss-teen-usa-south-carolina
# 3  2008-12-10                  chocolate-rain
# 4  2008-12-10           crank-that-soulja-boy
# 5  2008-12-12  all-your-base-are-belong-to-us
# 6  2008-12-12                   star-wars-kid
# 7  2008-12-12                           o-rly
# 8  2008-12-12             leave-britney-alone
# 9  2008-12-12                  i-like-turtles

# %% [markdown]
# ##  Find the top 10 social network origins (excluding ‘unknown’ origin and normalizing terms).

# %%
connection.rollback()
query="""
SELECT count(meme_kym_id) as total, origin  
FROM memes_dim 
WHERE origin <> 'Unknown'
GROUP BY origin order by total desc, origin 
LIMIT 10;
"""
dat = pd.read_sql_query(query, connection)
dat.head(10)
# Out:
#    total     origin
# 0    877    YouTube
# 1    593    Twitter
# 2    540      4chan
# 3    399     Tumblr
# 4    357     Reddit
# 5    198   niconico
# 6    163   Facebook
# 7     94      YTMND
# 8     76  Instagram
# 9     72       Vine

# %% [markdown]
# ##   Which memes have the largest number of common tags?

# %%
connection.rollback()
query="""
SELECT 
    msf.common_tags,
    msf.tags_similarity,
	m1.meme_kym_id as meme1Id,
	m2.meme_kym_id as meme2Id,
    m1.tags as tags1,
	m2.tags as tags2

FROM memes_similarity_facts msf
INNER JOIN memes_dim m1 ON m1.meme_kym_id=msf.meme_id1
INNER JOIN memes_dim m2 ON m2.meme_kym_id=msf.meme_id2

ORDER BY msf.common_tags desc, tags_similarity desc
LIMIT 10
"""
dat = pd.read_sql_query(query, connection)
dat.head(10)
# Out:
#    common_tags  tags_similarity                      meme1id  \
# 0            9             1.00                  im-so-happy
# 1            9             1.00            sakura-reflection
# 2            9             0.75       kirby-sky-high-remixes
# 3            9             0.75  kirbys-gourmet-race-remixes
# 4            9             0.68                oh-man-oh-god
# 5            9             0.68            theyre-eating-her
# 6            8             0.96      clash-on-the-big-bridge
# 7            8             0.96              decisive-battle
# 8            8             0.88                  dancing-mad
# 9            8             0.88              decisive-battle
#
#                        meme2id  \
# 0            sakura-reflection
# 1                  im-so-happy
# 2  kirbys-gourmet-race-remixes
# 3       kirby-sky-high-remixes
# 4            theyre-eating-her
# 5                oh-man-oh-god
# 6              decisive-battle
# 7      clash-on-the-big-bridge
# 8              decisive-battle
# 9                  dancing-mad
#
#                                                tags1  \
# 0  [a midsummer night's lewd dream, bemani, japan...
# 1  [a midsummer night's lewd dream, bemani, japan...
# 2  [game music, japan, kirby, kirby super star, m...
# 3  [game music, japan, kirby, kirby super star, m...
# 4  [b movie, catchphrase, film, movie, movie quot...
# 5  [b movie, film, movie, nostalgia, pop culture ...
# 6  [cover, final fantasy, japan, mad video, nicon...
# 7  [cover, final fantasy, japan, mad video, nicon...
# 8  [cover, dancing mad, final fantasy, japan, mad...
# 9  [cover, final fantasy, japan, mad video, nicon...
#
#                                                tags2
# 0  [a midsummer night's lewd dream, bemani, japan...
# 1  [a midsummer night's lewd dream, bemani, japan...
# 2  [game music, japan, kirby, kirby super star, m...
# 3  [game music, japan, kirby, kirby super star, m...
# 4  [b movie, film, movie, nostalgia, pop culture ...
# 5  [b movie, catchphrase, film, movie, movie quot...
# 6  [cover, final fantasy, japan, mad video, nicon...
# 7  [cover, final fantasy, japan, mad video, nicon...
# 8  [cover, final fantasy, japan, mad video, nicon...
# 9  [cover, dancing mad, final fantasy, japan, mad...

# %% [markdown]
# ##   Data augmentation. Given a meme, find the most similar memes in the data set based on

# %% [markdown]
# ### 1) similarity based on cosine similarity using the "description" of each meme as input and

# %%
connection.rollback()
query="""
select 
	msf.desc_similarity,
	msf.common_tags,
	msf.tags_similarity,
	m1.meme_kym_id as meme1Id,
	m2.meme_kym_id as meme2Id,
	m1.description as meme1Description,
	m2.description as meme2Description,
	m1.tags as meme1Tags,
	m2.tags as meme1Tags

from memes_similarity_facts msf
inner join memes_dim m1 ON m1.meme_kym_id=msf.meme_id1
inner join memes_dim m2 ON m2.meme_kym_id=msf.meme_id2

where msf.common_tags = 0 and msf.desc_similarity > 0.5
order by msf.desc_similarity desc
LIMIT 10
"""
dat = pd.read_sql_query(query, connection)
dat.head(10)
# Out:
#    desc_similarity  common_tags  tags_similarity  \
# 0             1.00            0              0.0
# 1             1.00            0              0.0
# 2             1.00            0              0.0
# 3             1.00            0              0.0
# 4             0.84            0              0.0
# 5             0.84            0              0.0
# 6             0.81            0              0.0
# 7             0.81            0              0.0
# 8             0.80            0              0.0
# 9             0.80            0              0.0
#
#                                            meme1id  \
# 0                                princess-celestia
# 1                                 twilight-sparkle
# 2                                princess-celestia
# 3                                           rarity
# 4                           expectation-vs-reality
# 5                        name-brand-vs-great-value
# 6                                        applejack
# 7                                princess-celestia
# 8  were-going-to-read-the-little-dolphin-who-cried
# 9                                     buster-sword
#
#                                         meme2id  \
# 0                              twilight-sparkle
# 1                             princess-celestia
# 2                                        rarity
# 3                             princess-celestia
# 4                     name-brand-vs-great-value
# 5                        expectation-vs-reality
# 6                             princess-celestia
# 7                                     applejack
# 8  hey-plankton-can-our-first-song-go-like-this
# 9                 interstellar-docking-parodies
#
#                                     meme1description  \
# 0  Use the main My Little Pony: Friendship is Mag...
# 1  Use the main My Little Pony: Friendship is Mag...
# 2  Use the main My Little Pony: Friendship is Mag...
# 3  Use the main My Little Pony: Friendship is Mag...
# 4  Expectation Vs. Reality refers to a series of ...
# 5  Name Brand vs. Great Value refers to a series ...
# 6  Please use the My Little Pony : Friendship is ...
# 7  Use the main My Little Pony: Friendship is Mag...
# 8  The Little Dolphin Who Cried is a scene that h...
# 9     [Warning: This entry contains major spoilers!]
#
#                                     meme2description  \
# 0  Use the main My Little Pony: Friendship is Mag...
# 1  Use the main My Little Pony: Friendship is Mag...
# 2  Use the main My Little Pony: Friendship is Mag...
# 3  Use the main My Little Pony: Friendship is Mag...
# 4  Name Brand vs. Great Value refers to a series ...
# 5  Expectation Vs. Reality refers to a series of ...
# 6  Use the main My Little Pony: Friendship is Mag...
# 7  Please use the My Little Pony : Friendship is ...
# 8  Hey Plankton! Can our first song go like this?...
# 9        (Note: This Entry Contains Major Spoilers!)
#
#                                            meme1tags  \
# 0  [celestia, character, mlp, molestia, my little...
# 1  [alicorn, fim, friendship is magic, mlp charac...
# 2  [celestia, character, mlp, molestia, my little...
# 3  [derpibooru, friendship is magic, gibbontake, ...
# 4  [borders, burger king, comparison, fail, nigah...
# 5  [beyonce, beyoncé, black twitter, comparisons,...
# 6  [applejack, friendship is magic, mlp character...
# 7  [celestia, character, mlp, molestia, my little...
# 8   [dolphin, fairly odd parents, youtube poop, ytp]
# 9  [cloud, final fantasy, final fantasy vii, jrpg...
#
#                                            meme1tags
# 0  [alicorn, fim, friendship is magic, mlp charac...
# 1  [celestia, character, mlp, molestia, my little...
# 2  [derpibooru, friendship is magic, gibbontake, ...
# 3  [celestia, character, mlp, molestia, my little...
# 4  [beyonce, beyoncé, black twitter, comparisons,...
# 5  [borders, burger king, comparison, fail, nigah...
# 6  [celestia, character, mlp, molestia, my little...
# 7  [applejack, friendship is magic, mlp character...
# 8            [hey, plankton, spongebob, squarepants]
# 9    [docking, fan, interstellar, parody, satellite]

# %% [markdown]
# ### 2) the number of common tags.

# %% [markdown]
# ##   Data augmentation. Is it possible to find two memes that have their description similarityscore above 90% but have few tags in common tags?

# %%
connection.rollback()
query="""
select 
	msf.desc_similarity,
	msf.common_tags,
	msf.tags_similarity,
	m1.meme_kym_id as meme1Id,
	m2.meme_kym_id as meme2Id,
	m1.description as meme1Description,
	m2.description as meme2Description,
	m1.tags as meme1Tags,
	m2.tags as meme1Tags

from memes_similarity_facts msf
inner join memes_dim m1 ON m1.meme_kym_id=msf.meme_id1
inner join memes_dim m2 ON m2.meme_kym_id=msf.meme_id2

where 
    msf.common_tags = 0 AND msf.desc_similarity > 0.9
order by msf.desc_similarity desc
LIMIT 10
"""
dat = pd.read_sql_query(query, connection)
dat.head(10)
# Out:
#    desc_similarity  common_tags  tags_similarity            meme1id  \
# 0              1.0            0              0.0             rarity
# 1              1.0            0              0.0   twilight-sparkle
# 2              1.0            0              0.0  princess-celestia
# 3              1.0            0              0.0  princess-celestia
#
#              meme2id                                   meme1description  \
# 0  princess-celestia  Use the main My Little Pony: Friendship is Mag...
# 1  princess-celestia  Use the main My Little Pony: Friendship is Mag...
# 2             rarity  Use the main My Little Pony: Friendship is Mag...
# 3   twilight-sparkle  Use the main My Little Pony: Friendship is Mag...
#
#                                     meme2description  \
# 0  Use the main My Little Pony: Friendship is Mag...
# 1  Use the main My Little Pony: Friendship is Mag...
# 2  Use the main My Little Pony: Friendship is Mag...
# 3  Use the main My Little Pony: Friendship is Mag...
#
#                                            meme1tags  \
# 0  [derpibooru, friendship is magic, gibbontake, ...
# 1  [alicorn, fim, friendship is magic, mlp charac...
# 2  [celestia, character, mlp, molestia, my little...
# 3  [celestia, character, mlp, molestia, my little...
#
#                                            meme1tags
# 0  [celestia, character, mlp, molestia, my little...
# 1  [celestia, character, mlp, molestia, my little...
# 2  [derpibooru, friendship is magic, gibbontake, ...
# 3  [alicorn, fim, friendship is magic, mlp charac...

# %% [markdown]
# * Data augmentation. Using the Google Vision data enrichment available data, get the distri-bution of safeness categories (adult, spoof, medical, violence and racy) as percentage of allthe memes analyzed.
